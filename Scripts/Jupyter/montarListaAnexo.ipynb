# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup as bs
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
from time import sleep

# %%
#Caminho para iniciar ChromeDriver
options = webdriver.ChromeOptions() 
options.add_experimental_option('excludeSwitches', ['enable-logging'])
driver = webdriver.Chrome(options=options,executable_path=r'G:\Drives compartilhados\Pontte\Operações\Automações\contaQI\Driver\chromedriver.exe')

# %%
def fazerLogin():
    #Site que irá abrir
    driver.get('https://app.pipefy.com/')

    sleep(5)

    #### Inicio Processo de Login ####

    #Identifica e retorna os elementos
    print('Inicio do processo de login')
    inserirEmail_element = driver.find_element_by_name('username')
    inseirSenha_element =  driver.find_element_by_name('password')
    entrar_element =  driver.find_element_by_name('submit')

    #InserirValores
    inserirEmail_element.send_keys('matheus.pereira@pontte.com.br')
    inseirSenha_element.send_keys('Pontte2000')
    print('login realizado')

    #Clicar
    entrar_element.click()
    sleep(2)
fazerLogin()
# Out:
# Inicio do processo de login
# login realizado

# %%
driver.get('https://app.pipefy.com/open-cards/513879355')
sleep(5)
driver.find_element_by_id("AnexosTab").click()
sleep(5)
soup = bs(driver.page_source, 'html.parser')

# %%
#soup

# %%
nomeAnexos = soup.findAll('div', {'class' : 'pp-area-actions pp-area-actions-left'})
tituloAnexo = []
for nomeAnexo in nomeAnexos:
    anexoDownload = nomeAnexo.find('span').text
    tituloAnexo.append(anexoDownload)
    #print(teste)

print(tituloAnexo)
# Out:
# ['Anexos do Email', 'Proposta', 'Proposta', 'Bacen', 'BACEN', 'Certidão de Estado Civil ', 'Comprovante de Residência', 'Extrato Bancário Últimos 3 meses (Restored)', 'Precisamos de uma foto do seu RG, CNH ou RNE', 'Foto de RG ou CNH - 2o Pagador(a)', 'Documentos dos vendedores', 'IRPF', 'Matrícula do imóvel', 'CCV', 'Capa IPTU', 'Fotos do imóvel', 'Contrato Social', 'Balanço Patrimonial 3 anos', 'DRE 3 anos', 'Faturamento 3 anos']

# %%
anexos = soup.findAll('div', {'data-testid' : 'attachments-list-items'})
href =[]
for anexo in anexos:
    anexo = anexo.find('a', {'data-testid' : 'attachment-item-trigger'})
    href.append(anexo['href'])
#print(href)

# %%
keyValue = {'Anexos do Email': [], 'Bacen':[], 'Certidão de Estado Civil ': [], 
            'Comprovante de Residência': [], 'Extrato Bancário Últimos 3 meses (Restored)': [],
            'Precisamos de uma foto do seu RG, CNH ou RNE':[], 'Foto de RG ou CNH - 2o Pagador(a)':[],
            'IRPF': [], 'Extrato bancário últimos 3 meses (2º proponente)': [], 'Holerite':[],
            'Holerite (2º proponente)':[], 'Contrato Social':[], 'Faturamento 3 anos':[],
            'Balanço Patrimonial 3 anos':[], 'DRE 3 anos':[], 'Matrícula do imóvel':[], 'CCV': [],
            'Capa IPTU':[], 'Fotos do imóvel':[]
            }

listaAnexoEmail =[]
listaAnexoBacen = []
listaAnexoEstadoCivil = []
listaAnexoComprovanteRes =[]
listaAnexoExtrato = []
listaAnexoDocumento = []
listaAnexoDocumento2 = []
listaAnexoIRPF = []
listaAnexoExtrato2 = []
listaAnexoHolerite = []
listaAnexoHolerite2 = []
#Lista PJ
listaAnexoContratoSocial = []
listaAnexoFaturamento3Anos = []
listaAnexoBalanco = []
listaAnexoDRE = []
listaAnexoMatricula = []
listaAnexoCCV = []
listaAnexoCapaIPTU = []
listaAnexoFotoImovel = []

html1 = soup.find('div', {'class':'pp-box-content'})
for divPrincipal in html1:
    titulo = divPrincipal.find('span')
    if titulo is not None:
        if titulo.text == 'Anexos do Email':
            conteudo = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoEmail in conteudo:
                listaAnexoEmail.append(anexoEmail['href'])
        if titulo.text == 'Bacen' or titulo.text == 'BACEN':
            conteudo2 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoBacen in conteudo2:
                listaAnexoBacen.append(anexoBacen['href'])
        if titulo.text == 'Certidão de Estado Civil ':
            conteudo3 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoEstado in conteudo3:
                listaAnexoEstadoCivil.append(anexoEstado['href'])
        if titulo.text == 'Comprovante de Residência':
            conteudo4 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoComprovante in conteudo4:
                listaAnexoComprovanteRes.append(anexoComprovante['href'])
        if titulo.text == 'Extrato Bancário Últimos 3 meses (Restored)':
            conteudo5 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoExtrato in conteudo5:
                listaAnexoExtrato.append(anexoExtrato['href'])
        if titulo.text == 'Precisamos de uma foto do seu RG, CNH ou RNE':
            conteudo6 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoDocumento in conteudo6:
                listaAnexoDocumento.append(anexoDocumento['href'])
        if titulo.text == 'Foto de RG ou CNH - 2o Pagador(a)':
            conteudo7 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoDocumento2 in conteudo7:
                listaAnexoDocumento2.append(anexoDocumento2['href'])
        if titulo.text == 'IRPF':
            conteudo8 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoIRPF in conteudo8:
                listaAnexoIRPF.append(anexoIRPF['href'])
        if titulo.text == 'Extrato bancário últimos 3 meses (2º proponente)':
            conteudo9 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoExtrato2 in conteudo9:
                listaAnexoExtrato2.append(anexoExtrato2['href'])
        if titulo.text == 'Holerite':
            conteudo10 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoHolerite in conteudo10:
                listaAnexoHolerite.append(anexoHolerite['href'])
        if titulo.text == 'Holerite (2º proponente)':
            conteudo11 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoHolerite2 in conteudo11:
                listaAnexoHolerite2.append(anexoHolerite2['href'])
        #Novos IF
        if titulo.text == 'Contrato Social':
            conteudo12 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoContratoSocial in conteudo12:
                listaAnexoContratoSocial.append(anexoContratoSocial['href'])
        if titulo.text == 'Faturamento 3 anos':
            conteudo13 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoFaturamento3Anos in conteudo13:
                listaAnexoFaturamento3Anos.append(anexoFaturamento3Anos['href'])
        if titulo.text == 'Balanço Patrimonial 3 anos':
            conteudo14 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoBalanco in conteudo14:
                listaAnexoBalanco.append(anexoBalanco['href'])
        if titulo.text == 'DRE 3 anos':
            conteudo15 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoDRE in conteudo15:
                listaAnexoDRE.append(anexoDRE['href'])
        if titulo.text == 'Matrícula do imóvel':
            conteudo16 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoMatricula in conteudo16:
                listaAnexoMatricula.append(anexoMatricula['href'])
        if titulo.text == 'CCV':
            conteudo17 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoCCV in conteudo17:
                listaAnexoCCV.append(anexoCCV['href'])
        if titulo.text == 'Capa IPTU':
            conteudo18 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoCapaIPTU in conteudo18:
                listaAnexoCapaIPTU.append(anexoCapaIPTU['href'])
        if titulo.text == 'Fotos do imóvel':
            conteudo19 = divPrincipal.find_all('a', {'class' : 'StyledAnchor-pstyle__sc-112a9fu-0 ccMLjg pp-margin-right-16 pp-no-margin pp-anchor'})
            for anexoFotos in conteudo19:
                listaAnexoFotoImovel.append(anexoFotos['href'])

keyValue['Anexos do Email'] = listaAnexoEmail  
keyValue['Bacen'] = listaAnexoBacen    
keyValue['Certidão de Estado Civil '] = listaAnexoEstadoCivil    
keyValue['Comprovante de Residência'] = listaAnexoComprovanteRes    
keyValue['Extrato Bancário Últimos 3 meses (Restored)'] = listaAnexoExtrato    
keyValue['Precisamos de uma foto do seu RG, CNH ou RNE'] = listaAnexoDocumento    
keyValue['Foto de RG ou CNH - 2o Pagador(a)'] = listaAnexoDocumento2    
keyValue['IRPF'] = listaAnexoIRPF
keyValue['Extrato bancário últimos 3 meses (2º proponente)'] = listaAnexoExtrato2
keyValue['Holerite'] = listaAnexoHolerite
keyValue['Holerite (2º proponente)'] = listaAnexoHolerite2
keyValue['Contrato Social'] = listaAnexoContratoSocial
keyValue['Faturamento 3 anos'] = listaAnexoFaturamento3Anos
keyValue['Balanço Patrimonial 3 anos'] = listaAnexoBalanco
keyValue['DRE 3 anos'] = listaAnexoDRE
keyValue['Matrícula do imóvel'] = listaAnexoMatricula
keyValue['CCV'] = listaAnexoCCV
keyValue['Capa IPTU'] = listaAnexoCapaIPTU
keyValue['Fotos do imóvel'] = listaAnexoFotoImovel

keyValue
# Out:
# {'Anexos do Email': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/b4b4519e-d8bb-469a-8b1c-1c66e85a30b5/image002-11.png'],
#  'Bacen': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/e82d0fbc-0915-485e-b531-a19719d32bc8/QINGTIANHUANG-23682983805-2022-03-30.json',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/beaf3137-f391-435f-b2ac-27f29087c9f8/3f2ed4c9-9690-455e-b434-bd891730f4d9.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/5dcb222b-c28c-4a43-9a64-28183163e389/QINGTIANHUANG-23682983805-2022-03-30.json',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/da4e5894-ca77-444a-a491-560a65f8dbc6/3f2ed4c9-9690-455e-b434-bd891730f4d9.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/a374a501-746b-4538-8ce5-2f79eef94c27/ZHULINYU-23776198869-2022-04-20.json',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/3c947a3b-e491-4d7b-bfd3-99112ae5f508/1a1d4168-addf-410c-9b2f-f85e1226a734.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/c58820b2-2246-4216-8e73-a8bd51e9627a/STRONGDOBRASILCOMERCIOIMPORTACAOEEXPORTACAOLTDA-20259774000149-2022-04-22.json',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/d2b80b41-de52-4069-a8f1-d678598d7fe3/92e966d4-609b-4068-9219-aac363d389c1.pdf'],
#  'Certidão de Estado Civil ': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/e92ad92f-8434-4f74-bbaa-12704763b98d/Huang21.jpg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/e8c0a353-9d22-4210-9837-a01e04faebe2/Huang11.jpg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/a91e161f-a11e-4efd-b857-d3010ae71300/Huang1.jpg'],
#  'Comprovante de Residência': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/9b43bb75-b0f7-47db-8e4f-b33e0c489a7d/WhatsAppImage2022-03-30at15.29.40.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/e457211a-bea6-46cf-b2d1-0b5c2dc27236/Comprovendereo.jpeg'],
#  'Extrato Bancário Últimos 3 meses (Restored)': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/1c67efd9-f9df-4e53-b70f-0de72e4a5d20/extrato-itau_27_03_2022_145020.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/a395818d-c9cf-44e9-a701-aa4e67a7dff4/extrato-itau_27_03_2022_071817.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/5bad699b-0659-4472-bb03-84ae54cdcdaa/extrato-itau_27_03_2022_071802.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/85812b8e-0f08-4003-8ba8-a0bca1adbc5c/extrato-itau_27_03_2022_071744.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/d37fe795-7aed-4256-8ed5-e88b31587f80/extrato-itau_27_03_2022_071727.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/beb6d989-2848-4d21-9106-b7318d7812d3/extrato-itau_27_03_2022_071712.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/0008dcc8-7c8e-4779-bd25-b0fba4967fcf/extrato-itau_27_03_2022_071657.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/7d9f8308-418e-48e9-8712-bd0e149a1cdd/extrato-itau_27_03_2022_071643.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/dedc0477-37b9-4fd7-9671-a3321e780be7/extrato-itau_27_03_2022_071629.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/a8b927f7-0634-49a3-8d9b-a13b7dede69c/extrato-itau_27_03_2022_071614.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/0b6dfdea-7d61-4a6c-822e-c08391037648/extrato-itau_27_03_2022_071559.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/2ee9951c-27ae-4adb-987d-7dc1e8e69fd7/extrato-itau_27_03_2022_071543.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/7838d1f1-f424-419d-accb-379a08e564e2/extrato-itau_27_03_2022_071503.pdf'],
#  'Precisamos de uma foto do seu RG, CNH ou RNE': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/b57d72c1-3406-4568-9495-e9c3cacf5685/extrato-itau_27_03_2022_071503.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/734161a3-1c48-482f-afdb-abd41f01a665/extrato-itau_27_03_2022_071543.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/3659eadd-a272-487e-9d59-dba694659ef6/extrato-itau_27_03_2022_071559.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/e80e895c-8e61-45ee-8adb-86b30f030af4/extrato-itau_27_03_2022_071614.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/8d15d1d4-7a4e-47f8-bf78-bf5cb0a7f4cb/extrato-itau_27_03_2022_071629.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/b7d560c2-fb71-4ba1-b485-c71214575753/extrato-itau_27_03_2022_071643.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/8e3ce587-ebdb-4f5a-9040-22cde85a4a24/extrato-itau_27_03_2022_071657(1).pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/8f4001ee-d00f-40cf-b459-7908a45f8fe2/extrato-itau_27_03_2022_071657.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/ef8a89ef-d2cd-44ec-93a6-7288e35af40d/extrato-itau_27_03_2022_071712.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/669b436f-350f-4872-9ce4-603c9d43119e/extrato-itau_27_03_2022_071727.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/b229b9d2-40a7-476f-8548-e91df9328d6f/extrato-itau_27_03_2022_071744.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/44867499-c975-431c-afd7-430081927ded/extrato-itau_27_03_2022_071802.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/c011bfba-99c2-4b67-bf4b-a23ae1bd3690/extrato-itau_27_03_2022_071817.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/8ccc0017-9ea8-4303-9c52-4e91355215da/extrato-itau_27_03_2022_145020.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/dfeedd3e-6fa7-4041-a21a-40f108457b23/Huang.jpg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/08a1f595-766e-4669-b263-fe42e8c425dc/Huang1.jpg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/e209f0bc-f300-4ee0-833a-b876e78408a6/Huang2.jpg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/35e7b986-3b90-47f5-8741-99427db8f56f/Habilitao.pdf'],
#  'Foto de RG ou CNH - 2o Pagador(a)': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/e917cb46-0020-48ad-9324-92bbff0dcfc3/DOCRG.jpeg'],
#  'IRPF': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/a4a401f2-a48f-4e97-9ef8-7763a1866d92/ZHULINYUIRF2.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/a838d845-c1e9-418b-a40b-16b4e8d0850c/ZHULINYUIRF1.pdf'],
#  'Extrato bancário últimos 3 meses (2º proponente)': [],
#  'Holerite': [],
#  'Holerite (2º proponente)': [],
#  'Contrato Social': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/a39b6449-e162-4aa8-be08-c192557c3767/CNPJ.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/c80a6e14-8019-4f6d-9b0b-ae236ead47b6/9CONTRATODESTRONG.pdf'],
#  'Faturamento 3 anos': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/b52eedc6-c7e8-40ea-a0e3-70b9351526b3/FATURAMENTO2021.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/d54ad3be-2084-4c8c-8d78-d837632a19d1/FATURAMENTO2020.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/bf550b73-acc3-4c5a-b971-e3aa6ffea8e9/FATURAMENTO2019.pdf'],
#  'Balanço Patrimonial 3 anos': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/db2cb8c0-6b4e-43af-813d-791612bc67e2/BALANO2021.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/704c62a1-7330-4756-b9cf-2130d8a8a1d5/BALANO2020.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/31682046-e98f-4140-9d2d-4864f6656fe0/BALANO2019.pdf'],
#  'DRE 3 anos': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/5eb9c3a6-4693-40ad-838a-ba93f4211be7/DRE2021.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/a5143c2a-14c0-4e34-85af-40b474f90df5/DRE2019.pdf',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/b40f24a7-43ac-4ef4-ade1-8ed8b8fdaab6/DRE-903-2020.pdf'],
#  'Matrícula do imóvel': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/9816e978-ce12-423d-af23-fed6898d3484/Matricula_174066_cod517111.pdf'],
#  'CCV': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/ada29145-21f3-45df-83fe-4d29fd5485c3/INSTRUMENTOPARTICULARDECOMPROMISSODEVENDAECOMPRADEIMVEL.docx-Clicksign.pdf'],
#  'Capa IPTU': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/4d4965fc-6181-4f9c-a6c7-ea7d581f7f11/CertidaoDadosCad41.pdf'],
#  'Fotos do imóvel': ['https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/2c801be3-f424-4f75-a842-00d0884bc980/WhatsAppImage2022-04-20at09.22.584.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/eabc207f-3451-4cbe-a9ea-7a1ab866c0e4/WhatsAppImage2022-04-20at09.22.583.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/29d38cdb-5f2d-4bcc-a60e-9a21a6b65338/WhatsAppImage2022-04-20at09.22.582.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/9d3a2b92-54fe-4009-912c-c776ce347e86/WhatsAppImage2022-04-20at09.22.581.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/4530e451-83c1-4a32-8ab2-df4afb5ea1bd/WhatsAppImage2022-04-20at09.22.58.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/6dce3f81-3616-4d10-a46f-ee27899a25af/WhatsAppImage2022-04-20at09.22.572.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/4100a297-2fa6-439e-acde-84c1a5eda80b/WhatsAppImage2022-04-20at09.22.571.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/ff834521-3dbb-4196-82f5-814956c323dc/WhatsAppImage2022-04-20at09.22.57.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/6897d18e-59a9-4274-835a-c9c47932e94d/WhatsAppImage2022-04-20at09.22.562.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/c2fe6839-eacd-4819-b99b-3745a3adb49b/WhatsAppImage2022-04-20at09.22.561.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/3ac050c3-6556-4875-8640-4b13ca954003/WhatsAppImage2022-04-20at09.22.56.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/cd8cb14b-236b-4e4f-8352-7fc650cc043a/WhatsAppImage2022-04-20at09.22.553.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/b2f74220-2aac-48b9-a77c-174acac06c31/WhatsAppImage2022-04-20at09.22.552.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/9a504591-8bd8-4ab1-9d4d-9323bd7158cb/WhatsAppImage2022-04-20at09.22.551.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/dafe1fa4-2dd2-4886-bfbd-ce844a98ca72/WhatsAppImage2022-04-20at09.22.55.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/1499d952-4b9a-4d46-a9bf-36c4890f2cf0/WhatsAppImage2022-04-20at09.22.544.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/f6d7fac1-f470-4cb3-a74f-722ba140dcff/WhatsAppImage2022-04-20at09.22.543.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/4bc3d41e-cd8d-4cb3-b96b-51cc68b95524/WhatsAppImage2022-04-20at09.22.542.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/be24105b-5060-4faf-86d3-ce3b1185df38/WhatsAppImage2022-04-20at09.22.541.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/3c34bba3-9fce-4f72-8791-0227289688a3/WhatsAppImage2022-04-20at09.22.54.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/4d52354c-c681-4c0a-8496-f5216b24ab41/WhatsAppImage2022-04-20at09.22.533.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/61a1cd72-e84f-4584-8e48-d3cd2484e7d8/WhatsAppImage2022-04-20at09.22.532.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/e090eec5-9459-4f65-925f-aab88ece063b/WhatsAppImage2022-04-20at09.22.531.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/915bbfba-800e-4284-a8a5-b9ae06ac87cf/WhatsAppImage2022-04-20at09.22.53.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/da4181e3-4442-4c45-a551-7b060c0e7471/WhatsAppImage2022-04-20at09.22.521.jpeg',
#   'https://app-storage-service.pipefy.com/v1/resources/cards-v1/513879355/uploads/dde1853e-7f25-4fc3-a320-b22edab6b0bc/WhatsAppImage2022-04-20at09.22.52.jpeg']}
